# %%
#4.绘制正弦曲线
import numpy as np
import matplotlib.pyplot as plt

x=np.linspace(0,2*np.pi,1000)
y=np.sin(x)

plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('sin(x)')
plt.title('The graph of sine function (0,2π)')
plt.grid(True)
plt.show()
